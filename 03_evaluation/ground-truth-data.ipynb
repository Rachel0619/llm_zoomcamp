# %%
import requests 

docs_url = 'https://github.com/DataTalksClub/llm-zoomcamp/blob/main/01-intro/documents.json?raw=1'
docs_response = requests.get(docs_url)
documents_raw = docs_response.json()

documents = []

for course in documents_raw:
    course_name = course['course']

    for doc in course['documents']:
        doc['course'] = course_name
        documents.append(doc)

# %%
import hashlib

def generate_document_id(doc):
    combined = f"{doc['course']}-{doc['question']}"
    # combined = f"{doc['course']}-{doc['question']}-{doc['text'][:10]}"
    hash_object = hashlib.md5(combined.encode())
    hash_hex = hash_object.hexdigest()
    document_id = hash_hex[:8]
    return document_id

# %%
for doc in documents:
    doc['id'] = generate_document_id(doc)

# %%
documents[3]
# Out:
# {'text': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#  'section': 'General course-related questions',
#  'question': 'Course - I have registered for the Data Engineering Bootcamp. When can I expect to receive the confirmation email?',
#  'course': 'data-engineering-zoomcamp',
#  'id': '4e079edc'}

# %%
from collections import defaultdict

# %%
hashes = defaultdict(list)

for doc in documents:
    doc_id = doc['id']
    hashes[doc_id].append(doc)

# %%
len(hashes), len(documents)
# Out:
# (944, 948)

# %%
for k, values in hashes.items():
    if len(values) > 1:
        print(k)
# Out:
# ca3dc12d
# 960fb254
# 67d2f21c
# 297f443c

# %%
import json

with open('documents-with-ids.json', 'wt') as f_out:
    json.dump(documents, f_out, indent=2)

# %%
# !head documents-with-ids.json
# Out:
# [
#   {
#     "text": "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  \u201cOffice Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon\u2019t forget to register in DataTalks.Club's Slack and join the channel.",
#     "section": "General course-related questions",
#     "question": "Course - When will the course start?",
#     "course": "data-engineering-zoomcamp",
#     "id": "5f1b0231"
#   },
#   {
#     "text": "GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites",

# %%
prompt_template = """
You emulate a student who's taking our course.
Formulate 5 questions this student might ask based on a FAQ record. The record
should contain the answer to the questions, and the questions should be complete and not too short.
If possible, use as fewer words as possible from the record. 

The record:

section: {section}
question: {question}
answer: {text}

Provide the output in parsable JSON without using code blocks:

["question1", "question2", ..., "question5"]
""".strip()

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv() 
api_key = os.environ.get("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# %%
doc = documents[2]
prompt = prompt_template.format(**doc)

# %%
print(prompt)
# Out:
# You emulate a student who's taking our course.
# Formulate 5 questions this student might ask based on a FAQ record. The record
# should contain the answer to the questions, and the questions should be complete and not too short.
# If possible, use as fewer words as possible from the record.
#
# The record:
#
# section: General course-related questions
# question: Course - Can I still join the course after the start date?
# answer: Yes, even if you don't register, you're still eligible to submit the homeworks.
# Be aware, however, that there will be deadlines for turning in the final projects. So don't leave everything for the last minute.
#
# Provide the output in parsable JSON without using code blocks:
#
# ["question1", "question2", ..., "question5"]

# %%
response = client.chat.completions.create(
        model='gpt-4o',
        messages=[{"role": "user", "content": prompt}]
    )

json_response = response.choices[0].message.content
json_response
# Out:
# '[\n  "Is it possible to enter the course after it starts?",\n  "Can I enroll after the course has begun and still do the assignments?",\n  "Am I allowed to submit homework if I\'m not registered by the start date?",\n  "Will I face any restrictions on final project deadlines if I join late?",\n  "Can I delay registering for the course and work on assignments?"\n]'

# %%
# OpenAI

def generate_questions(doc):
    prompt = prompt_template.format(**doc)

    response = client.chat.completions.create(
        model='gpt-4o',
        messages=[{"role": "user", "content": prompt}]
    )

    json_response = response.choices[0].message.content
    return json_response

# %%
import requests
import json
from tqdm.auto import tqdm

def generate_questions_ollama(doc, model="llama3.2"):
    prompt = prompt_template.format(**doc)
    
    response = requests.post('http://localhost:11434/api/generate',
                           json={
                               'model': model,
                               'prompt': prompt,
                               'stream': False,
                           })
    
    if response.status_code == 200:
        return response.json()['response']
    else:
        print(f"Error: {response.status_code}")
        return "[]"

# Generate questions
results = {}

for doc in tqdm(documents):
    doc_id = doc['id']
    if doc_id in results:
        continue
    questions = generate_questions_ollama(doc)
    results[doc_id] = questions

print(f"Generated questions for {len(results)} documents")
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]
# Generated questions for 944 documents

# %%
import pickle

# Save the results
with open('results.bin', 'wb') as f:
    pickle.dump(results, f)

print(f"Results saved to results.bin")
# Out:
# Results saved to results.bin

# %%
# Generate 5 questions for each doc

# results = {}

# from tqdm.auto import tqdm
# for doc in tqdm(documents):
#     doc_id = doc['id']
#     if doc_id in results:
#         continue
#     questions = generate_questions(doc)
#     results[doc_id] = questions

# %%
# with open('results.bin', 'rb') as f_in:
#     results = pickle.load(f_in)

# %%
len(results)
# Out:
# 944

# %%
# results['58c9f99f'] = '''[
# r"How can I resolve the Docker error 'invalid mode: \Program Files\Git\\var\lib\postgresql\data'?",
# "What should I do if I encounter an invalid mode error in Docker on Windows?",
# "What is the correct mounting path to use in Docker for PostgreSQL data on Windows?",
# "Can you provide an example of a correct Docker mounting path for PostgreSQL data?",
# r"How do I correct the mounting path error in Docker for \Program Files\Git\var\lib\postgresql\data'?"
# ]'''

# %%
import ast
import json
import re

parsed_results = {}

def clean_and_parse_questions(json_questions):
    try:
        # First, try json.loads in case it's proper JSON array
        result = json.loads(json_questions)
        # If it's already a list, return it
        if isinstance(result, list):
            return result
        # If it's a dict, extract the values
        elif isinstance(result, dict):
            return list(result.values())
        else:
            return [str(result)]
    except json.JSONDecodeError:
        try:
            # Extract questions manually using regex - get the question text only
            questions = re.findall(r'"question\d+":\s*"([^"]+)"', json_questions)
            if questions:
                return questions
            
            # Try alternative regex patterns
            questions = re.findall(r'"([^"]*\?[^"]*)"', json_questions)
            if questions:
                return questions
                
            # If no questions found, try ast.literal_eval
            return ast.literal_eval(json_questions)
        except:
            # Last resort - split by common delimiters and clean
            lines = json_questions.split('\n')
            questions = []
            for line in lines:
                line = line.strip()
                if '?' in line and len(line) > 10:  # Likely a question
                    # Remove quotes and extra formatting
                    clean_question = re.sub(r'^["\'\s]*', '', line)
                    clean_question = re.sub(r'["\'\s]*$', '', clean_question)
                    clean_question = re.sub(r'^question\d+:\s*', '', clean_question, flags=re.IGNORECASE)
                    if clean_question:
                        questions.append(clean_question)
            return questions if questions else [json_questions]

for doc_id, json_questions in results.items():
    try:
        parsed_results[doc_id] = clean_and_parse_questions(json_questions)
    except Exception as e:
        print(f"Failed to parse doc_id {doc_id}: {e}")
        print(f"Content: {json_questions[:200]}...")
        continue

print(f"Successfully parsed {len(parsed_results)} documents")

# Check a sample to see what we got
if parsed_results:
    sample_doc_id = list(parsed_results.keys())[0]
    print(f"Sample parsed result: {parsed_results[sample_doc_id]}")
    print(f"Number of questions: {len(parsed_results[sample_doc_id])}")
# Out:
# Successfully parsed 944 documents
# Sample parsed result: ['What is the expected start time of the course and how will it be communicated to students?', "How do I access the live 'Office Hours' session at the beginning of the course?", 'Can I attend the course from a mobile device or only from a desktop computer?', 'What is the deadline for registering before the course starts?', 'Are there any other platforms besides Google Calendar and Slack that students should be aware of to stay updated on the course?']
# Number of questions: 5

# %%
doc_index = {d['id']:d for d in documents}

# %%
final_results = []

for doc_id, questions in parsed_results.items():
    course = doc_index[doc_id]['course']
    for q in questions:
        final_results.append((q, course, doc_id))

# %%
final_results
# Out:
# [('What is the expected start time of the course and how will it be communicated to students?',
#   'data-engineering-zoomcamp',
#   '5f1b0231'),
#  ("How do I access the live 'Office Hours' session at the beginning of the course?",
#   'data-engineering-zoomcamp',
#   '5f1b0231'),
#  ('Can I attend the course from a mobile device or only from a desktop computer?',
#   'data-engineering-zoomcamp',
#   '5f1b0231'),
#  ('What is the deadline for registering before the course starts?',
#   'data-engineering-zoomcamp',
#   '5f1b0231'),
#  ('Are there any other platforms besides Google Calendar and Slack that students should be aware of to stay updated on the course?',
#   'data-engineering-zoomcamp',
#   '5f1b0231'),
#  ('What are the specific requirements I need to fulfill before starting this course?',
#   'data-engineering-zoomcamp',
#   '58fa8869'),
#  ("Can you provide more details on what is meant by 'GitHub' in the context of course prerequisites?",
#   'data-engineering-zoomcamp',
#   '58fa8869'),
#  ('Are there any additional tools or software that I need to install before enrolling in the course?',
#   'data-engineering-zoomcamp',
#   '58fa8869'),
#  ('How do I link my GitHub account to access the required resources for the course?',
#   'data-engineering-zoomcamp',
#   '58fa8869'),
#  ('Can you provide a list of all necessary GitHub repositories and data engineering tools needed for this course?',
#   'data-engineering-zoomcamp',
#   '58fa8869'),
#  ('I am interested in joining this course but I missed the initial start date, can I still participate and turn in assignments after the initial deadline?',
#   'data-engineering-zoomcamp',
#   '04d2574d'),
#  ('How will I be able to submit my final projects if I join the course after the original start date?',
#   'data-engineering-zoomcamp',
#   '04d2574d'),
#  ('Can you confirm if there are additional requirements or any prerequisites for joining a course that started without me?',
#   'data-engineering-zoomcamp',
#   '04d2574d'),
#  ("Will I receive the same benefits as other students, such as access to online materials and instructor support, even though I'm joining late in the course?",
#   'data-engineering-zoomcamp',
#   '04d2574d'),
#  ('What kind of support will be available to students who join the course after it has already started?',
#   'data-engineering-zoomcamp',
#   '04d2574d'),
#  ("I have registered for the Data Engineering Bootcamp, but I'm still unsure about what to expect. What will be covered in the course?",
#   'data-engineering-zoomcamp',
#   '4e079edc'),
#  ('The confirmation email says nothing about registration being checked against a list. How does that work exactly?',
#   'data-engineering-zoomcamp',
#   '4e079edc'),
#  ("If registering for the bootcamp doesn't guarantee admission, then why would it help with interest gauging?",
#   'data-engineering-zoomcamp',
#   '4e079edc'),
#  ('How can I know if my submission will be accepted or not without receiving a confirmation email?',
#   'data-engineering-zoomcamp',
#   '4e079edc'),
#  ('What kind of feedback and support can I expect from instructors and peers during the course?',
#   'data-engineering-zoomcamp',
#   '4e079edc'),
#  ("I'm not familiar with Google Cloud. Can you recommend any tutorials or resources to help me get started?",
#   'data-engineering-zoomcamp',
#   '66038350'),
#  ('What is the most efficient way to set up Terraform and the other dependencies required for the course?',
#   'data-engineering-zoomcamp',
#   '66038350'),
#  ('Are there any specific versions of Python, Anaconda, or Git that I should use for this course?',
#   'data-engineering-zoomcamp',
#   '66038350'),
#  ('How can I ensure that my Google Cloud account is ready to go before the first day of class?',
#   'data-engineering-zoomcamp',
#   '66038350'),
#  ('Can you provide an outline of what topics are covered in the prerequisites section of the syllabus? Are they assumed knowledge or do I need to study them beforehand?',
#   'data-engineering-zoomcamp',
#   '66038350'),
#  ('How many Zoomcamps are held annually, and what are their respective start dates?',
#   'data-engineering-zoomcamp',
#   '8fc8eee5'),
#  ('Can I attend any of the Zoom Camps without enrolling in the certification program, or do they need to be taken concurrently with a live cohort?',
#   'data-engineering-zoomcamp',
#   '8fc8eee5'),
#  ('Are there separate Zoomcamp schedules for each course, such as Data-Engineering, MLOps, and Machine Learning?',
#   'data-engineering-zoomcamp',
#   '8fc8eee5'),
#  ("What is the general schedule for the Data-Engineering Zoomcamp 'live' cohort per year?",
#   'data-engineering-zoomcamp',
#   '8fc8eee5'),
#  ('Can I take the non-certification Zoom Camps at any time of the year, or are there specific dates when they become available?',
#   'data-engineering-zoomcamp',
#   '8fc8eee5'),
#  ('Will I need to learn any new tools or software for this course, and if so what exactly?',
#   'data-engineering-zoomcamp',
#   'afbf3447'),
#  ('How does the change in tools from Prefect/Airflow to Mage AI impact the learning experience?',
#   'data-engineering-zoomcamp',
#   'afbf3447'),
#  ('Can you explain why the terraform videos were re-recorded, was there an issue with the previous version?',
#   'data-engineering-zoomcamp',
#   'afbf3447'),
#  ('Will I be able to use any pre-existing knowledge or skills gained from previous courses if they were using Prefect/Airflow?',
#   'data-engineering-zoomcamp',
#   'afbf3447'),
#  ('Are there any plans for future changes or updates to the course materials and tools?',
#   'data-engineering-zoomcamp',
#   'afbf3447'),
#  ('Can I still access the course materials after it finishes? If so, how long will they be available?',
#   'data-engineering-zoomcamp',
#   'ab9965a7'),
#  ("How do I prepare for the next cohort of the course if I'm following the course materials on my own? Is there any additional guidance provided?",
#   'data-engineering-zoomcamp',
#   'ab9965a7'),
#  ("What is a final capstone project, and how do I get involved in it if I'm taking the course after it finishes?",
#   'data-engineering-zoomcamp',
#   'ab9965a7'),
#  ('Will there be any updates or changes to the course materials or content after the course finishes?',
#   'data-engineering-zoomcamp',
#   'ab9965a7'),
#  ('Are there any additional resources available for students who are following the course materials outside of the main course period?',
#   'data-engineering-zoomcamp',
#   'ab9965a7'),
#  ('What kind of support can I expect if I take the course in self-paced mode?',
#   'data-engineering-zoomcamp',
#   '9cf6c773'),
#  ('Is it possible to get help with my issues before reaching out to the Slack channel?',
#   'data-engineering-zoomcamp',
#   '9cf6c773'),
#  ('Can I find answers to all my questions in this FAQ document?',
#   'data-engineering-zoomcamp',
#   '9cf6c773'),
#  ('How can I use the @ZoomcampQABot feature effectively to get help with my queries?',
#   'data-engineering-zoomcamp',
#   '9cf6c773'),
#  ('Do I need to search only within the Slack channel, or are there other resources available?',
#   'data-engineering-zoomcamp',
#   '9cf6c773'),
#  ("I'm having trouble finding the videos for the course. Can you recommend a playlist on YouTube where I can refer to?",
#   'data-engineering-zoomcamp',
#   '5a990ed0'),
#  ('How do I access additional videos, such as office hours videos, that are specific to each year?',
#   'data-engineering-zoomcamp',
#   '5a990ed0'),
#  ('The year-specific playlists can be found by referring to the playlist below: https://youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb&si=NspQhtZhZQs1B9F-',
#   'data-engineering-zoomcamp',
#   '5a990ed0'),
#  ("I noticed that the playlist I'm looking at doesn't have a year specified. Does this mean it's an older playlist?",
#   'data-engineering-zoomcamp',
#   '5a990ed0'),
#  ('How can I access the updated version of the playlist on Github that has thumbnails and a direct link to each video?',
#   'data-engineering-zoomcamp',
#   '5a990ed0'),
#  ('I saw that the Main “DATA ENGINEERING” playlist is pinned to the slack channel. How can I access it there?',
#   'data-engineering-zoomcamp',
#   '5a990ed0'),
#  ('What is the expected time commitment for this course per week, and how can I estimate it based on my background and previous experience with modules?',
#   'data-engineering-zoomcamp',
#   'c699d56e'),
#  ('Can you provide more information about the time commitment required for the course, such as a specific range or a detailed breakdown of the expected hours?',
#   'data-engineering-zoomcamp',
#   'c699d56e'),
#  ('Are there any resources available to help me calculate the time commitment for the course based on my individual circumstances?',
#   'data-engineering-zoomcamp',
#   'c699d56e'),
#  ('How can I ensure that I am staying within the recommended time commitment of 5-15 hours per week, and what are the consequences if I exceed this range?',
#   'data-engineering-zoomcamp',
#   'c699d56e'),
#  ('Can you provide any examples or case studies of students who have successfully completed the course with varying levels of background experience, and how they managed their time effectively?',
#   'data-engineering-zoomcamp',
#   'c699d56e'),
#  ('Can I still receive a certificate if I complete a self-paced course?',
#   'data-engineering-zoomcamp',
#   '863e7ea8'),
#  ('How does the peer-review process work for capstone projects in the live cohort?',
#   'data-engineering-zoomcamp',
#   '863e7ea8'),
#  ('What happens if I miss the live cohort and decide to pursue self-paced mode?',
#   'data-engineering-zoomcamp',
#   '863e7ea8'),
#  ('Can I still get feedback on my projects in self-paced mode?',
#   'data-engineering-zoomcamp',
#   '863e7ea8'),
#  ('Are there any alternative options for earning a certificate besides completing with a live cohort?',
#   'data-engineering-zoomcamp',
#   '863e7ea8'),
#  ("I'm having trouble accessing the video stream for the Office Hours. Can you provide more information about how to do so?",
#   'data-engineering-zoomcamp',
#   'c1c39b35'),
#  ('If I miss the live office hour, will there be a recording available afterwards?',
#   'data-engineering-zoomcamp',
#   'c1c39b35'),
#  ("I want to submit my questions during an Office Hour, but don't see any options in the chat. How can I do so?",
#   'data-engineering-zoomcamp',
#   'c1c39b35'),
#  ('Can you explain how Slido works and why is it used for submitting questions during Office Hours?',
#   'data-engineering-zoomcamp',
#   'c1c39b35'),
#  ("I'm concerned that my question will get lost if I post it in the chat during an Office Hour. Is there a way to ensure my question gets seen by the instructors?",
#   'data-engineering-zoomcamp',
#   'c1c39b35'),
#  ("What happens if I miss the live Office Hours/workshop, and can't attend the recorded version afterwards either?",
#   'data-engineering-zoomcamp',
#   '7bcc7ed3'),
#  ('Can I only access the recorded Office Hours after they have ended for good?',
#   'data-engineering-zoomcamp',
#   '7bcc7ed3'),
#  ('Will there be a specific time frame in which I can watch the recorded Office Hours or is it available forever?',
#   'data-engineering-zoomcamp',
#   '7bcc7ed3'),
#  ('Are all aspects of the Office Hours/workshop covered in the recording, such as Q&A sessions?',
#   'data-engineering-zoomcamp',
#   '7bcc7ed3'),
#  ('How will I know that the recording of the live Office Hours is available when I want to access it?',
#   'data-engineering-zoomcamp',
#   '7bcc7ed3'),
#  ('What is the format of the homework and project submissions, and where can I find the latest deadlines?',
#   'data-engineering-zoomcamp',
#   'e1e06694'),
#  ('Will there be any extensions or late penalties for missing the homework and project deadlines?',
#   'data-engineering-zoomcamp',
#   'e1e06694'),
#  ('How will my progress on homework and projects be assessed, and what are the criteria for evaluation?',
#   'data-engineering-zoomcamp',
#   'e1e06694'),
#  ('Can I submit my homework and projects in groups, and if so, how do I register myself with my group members?',
#   'data-engineering-zoomcamp',
#   'e1e06694'),
#  ('Are there any additional resources or support available for students who need help with homework and project submissions?',
#   'data-engineering-zoomcamp',
#   'e1e06694'),
#  ("Will I still receive credit for my homework if it's submitted after the due date, but before the form is closed?",
#   'data-engineering-zoomcamp',
#   'a345f216'),
#  ('What happens to my late submission if I confirm by the timestamp on the Course page?',
#   'data-engineering-zoomcamp',
#   'a345f216'),
#  ('Can I get an extension on the deadline for late submissions?',
#   'data-engineering-zoomcamp',
#   'a345f216'),
#  ("Do you have a specific process for submitting homework that's already past its original due date?",
#   'data-engineering-zoomcamp',
#   'a345f216'),
#  ('If I submit my homework after the form is closed, how will it be treated in terms of grading?',
#   'data-engineering-zoomcamp',
#   'a345f216'),
#  ('What is considered a complete homework submission in terms of accessibility?',
#   'data-engineering-zoomcamp',
#   '2544a0f7'),
#  ("How do I ensure my GitHub repository or other storage location clearly indicates that it's related to our course work?",
#   'data-engineering-zoomcamp',
#   '2544a0f7'),
#  ('Can I submit my code if I have it hosted elsewhere (e.g. personal website, Dropbox)?',
#   'data-engineering-zoomcamp',
#   '2544a0f7'),
#  ('If I use a team repository for group projects, which one is considered the official submission?',
#   'data-engineering-zoomcamp',
#   '2544a0f7'),
#  ('What happens if my online storage location changes or becomes inaccessible after submitting homework?',
#   'data-engineering-zoomcamp',
#   '2544a0f7'),
#  ("I'm not sure how I should score points for my homework submissions. Can you provide more detail on what is counted towards the total?",
#   'data-engineering-zoomcamp',
#   '1fe7a0f0'),
#  ('How do I access my point total for a particular homework? Is it clearly displayed somewhere on that page?',
#   'data-engineering-zoomcamp',
#   '1fe7a0f0'),
#  ('If I contribute to the FAQ section, does that count as part of my overall points total?',
#   'data-engineering-zoomcamp',
#   '1fe7a0f0'),
#  ("I'm having trouble understanding how the leaderboard works. Can you explain the difference between points earned from Homeworks, FAQs, and Learning in Public?",
#   'data-engineering-zoomcamp',
#   '1fe7a0f0'),
#  ('Do I receive any bonus or penalty points for specific actions like earning an award or not meeting a certain deadline?',
#   'data-engineering-zoomcamp',
#   '1fe7a0f0'),
#  ("I'm not seeing my name on the leaderboard. How do I check if it's me?",
#   'data-engineering-zoomcamp',
#   'bacb5221'),
#  ('If I change my display name, will that show up on the leaderboard?',
#   'data-engineering-zoomcamp',
#   'bacb5221'),
#  ("I'm not sure what my Display name is. Can you give me an example?",
#   'data-engineering-zoomcamp',
#   'bacb5221'),
#  ("How do I know which leaderboard I'm supposed to be on? Is it based on a specific skill level or something?",
#   'data-engineering-zoomcamp',
#   'bacb5221'),
#  ('Can I change my display name after the course has started?',
#   'data-engineering-zoomcamp',
#   'bacb5221'),
#  ('Is Python 3.9 still officially recommended for use in this course in 2024, or should we start focusing on later versions like 3.10 and 3.11?',
#   'data-engineering-zoomcamp',
#   '8dcf278e'),
#  ("I'm using an older version of Python to follow along with the videos - is there any specific reason why I shouldn't upgrade to a more recent version for the sake of stability and troubleshooting?",
#   'data-engineering-zoomcamp',
#   '8dcf278e'),
#  ('Can you provide some guidance on how to identify if my Python environment is compatible with the course materials, or what kind of issues might arise from using an older version?',
#   'data-engineering-zoomcamp',
#   '8dcf278e'),
#  ('Are there any specific libraries or tools that are not compatible with Python 3.9, and if so, should we be aware of them when working on assignments?',
#   'data-engineering-zoomcamp',
#   '8dcf278e'),
#  ('If I upgrade to Python 3.10 or later, will my existing code still work as intended, or will I need to make significant changes to get it to run?',
#   'data-engineering-zoomcamp',
#   '8dcf278e'),
#  ('What are some common challenges I may encounter when setting up my environment on a local machine, and how can I overcome them?',
#   'data-engineering-zoomcamp',
#   '0d8b1118'),
#  ('Can you provide more information about Using GitHub Codespaces and Setting up the environment on a cloudVM codespace?',
#   'data-engineering-zoomcamp',
#   '0d8b1118'),
#  ('How do I determine which virtual machine to start with, Introduction to Docker or one of the other options?',
#   'data-engineering-zoomcamp',
#   '0d8b1118'),
#  ('Are there any specific differences between using my local laptop or PC versus working on GitHub Codespaces for this course?',
#   'data-engineering-zoomcamp',
#   '0d8b1118'),
#  ('What is the benefit of setting up a virtual machine compared to just using my local machine, and how does it impact my learning experience?',
#   'data-engineering-zoomcamp',
#   '0d8b1118'),
#  ('I am having trouble understanding how to set up my environment for this course. Can you provide more information on what tools and software are required?',
#   'data-engineering-zoomcamp',
#   'a8e4f239'),
#  ('In the course, we will be working with GitHub repositories, but I am not sure how to create a new repository or manage existing ones. Can you provide step-by-step instructions?',
#   'data-engineering-zoomcamp',
#   'a8e4f239'),
#  ('What are some tips for debugging my code when working with Git and Docker?',
#   'data-engineering-zoomcamp',
#   'a8e4f239'),
#  ('Will we be covering any specific version control systems in this course, or will Git be the primary focus?',
#   'data-engineering-zoomcamp',
#   'a8e4f239'),
#  ('How can I access additional resources, such as tutorials and documentation, if I am struggling with a particular concept or assignment?',
#   'data-engineering-zoomcamp',
#   'a8e4f239'),
#  ('What exactly is expected of me in terms of environment and infrastructure for the course, and how will my existing setup affect it?',
#   'data-engineering-zoomcamp',
#   'afa2bb4c'),
#  ('Can I use an alternative platform to GitHub Codespaces or GCP VM if I prefer? Are there any specific requirements?',
#   'data-engineering-zoomcamp',
#   'afa2bb4c'),
#  ('How do I know which environment or setup option is best suited for this course, and what factors should I consider?',
#   'data-engineering-zoomcamp',
#   'afa2bb4c'),
#  ("If I don't have experience with cloud-based environments like GCP VM or GitHub Codespaces, will I still be able to complete the course?",
#   'data-engineering-zoomcamp',
#   'afa2bb4c'),
#  ('Are there any additional costs associated with using a platform other than GitHub Codespaces or GCP VM for the course?',
#   'data-engineering-zoomcamp',
#   'afa2bb4c'),
#  ('Do I need to use both GitHub Codespaces and Google Cloud Platform (GCP) for this course, or is one sufficient?',
#   'data-engineering-zoomcamp',
#   'f4f9ccaa'),
#  ('How does learning BigQuery as part of GCP compare to using GitHub Codespaces alone, in terms of relevance to the end project?',
#   'data-engineering-zoomcamp',
#   'f4f9ccaa'),
#  ('Can I focus on setting up a local environment for most of the course and still meet the requirements for using GCP?',
#   'data-engineering-zoomcamp',
#   'f4f9ccaa'),
#  ('What are the advantages of choosing GitHub Codespaces over setting up a local environment for this course?',
#   'data-engineering-zoomcamp',
#   'f4f9ccaa'),
#  ("If I choose to use GCP, do I need to also learn other Google Cloud services that aren't directly related to BigQuery or the end project?",
#   'data-engineering-zoomcamp',
#   'f4f9ccaa'),
#  ("I'm trying to connect to a Google Cloud Platform (GCP) VM using VSCode on a Windows machine. I keep getting an error message when attempting to do so. Can you provide some more details about what's causing this issue?",
#   'data-engineering-zoomcamp',
#   '20cebc75'),
#  ('How do I open the Registry Editor on my Windows machine?',
#   'data-engineering-zoomcamp',
#   '20cebc75'),
#  ('What is the location of the known_hosts file in Windows?',
#   'data-engineering-zoomcamp',
#   '20cebc75'),
#  ('Can you provide more information about why deleting the fingerprint from the known_hosts file might resolve the issue?',
#   'data-engineering-zoomcamp',
#   '20cebc75'),
#  ('Are there any other potential solutions for resolving this issue, besides changing the registry value or deleting the fingerprint?',
#   'data-engineering-zoomcamp',
#   '20cebc75'),
#  ('Can I use other cloud providers like AWS or Azure if I prefer, or is GCP the only option?',
#   'data-engineering-zoomcamp',
#   '1bbe9a8d'),
#  ('Why is Google Cloud Platform (GCP) used in this course compared to other popular cloud services?',
#   'data-engineering-zoomcamp',
#   '1bbe9a8d'),
#  ("How can I take advantage of GCP's free trial period and $300 credits as a new user?",
#   'data-engineering-zoomcamp',
#   '1bbe9a8d'),
#  ('What are the requirements for signing up for a free GCP account, specifically regarding credit card information?',
#   'data-engineering-zoomcamp',
#   '1bbe9a8d'),
#  ('Are there any additional benefits or services available in other cloud providers that are not offered by GCP?',
#   'data-engineering-zoomcamp',
#   '1bbe9a8d'),
#  ("I am taking a course that requires me to use Google Cloud Platform (GCP) for my project. What is covered under the 'free trial' of GCP?",
#   'data-engineering-zoomcamp',
#   '22d486b7'),
#  ('If I choose to pay for cloud services, will I be eligible for any discounts or promotions?',
#   'data-engineering-zoomcamp',
#   '22d486b7'),
#  ('How do I access and manage my free resources on GCP?',
#   'data-engineering-zoomcamp',
#   '22d486b7'),
#  ('Can I use a combination of paid and free resources on GCP for my project?',
#   'data-engineering-zoomcamp',
#   '22d486b7'),
#  ('Will the cost of cloud services affect my grade in this course?',
#   'data-engineering-zoomcamp',
#   '22d486b7'),
#  ("I'm concerned about being able to run the course materials, especially BigQuery. Can you provide a list of alternatives for running the BigQuery components locally?",
#   'data-engineering-zoomcamp',
#   '93dbebeb'),
#  ('Are there any specific modules or topics in the course that absolutely require Google Cloud Platform (GCP) to function properly?',
#   'data-engineering-zoomcamp',
#   '93dbebeb'),
#  ('How do I set up my local environment to mirror the GCP environment, and are there any tutorials or resources available for this?',
#   'data-engineering-zoomcamp',
#   '93dbebeb'),
#  ('If most of the course materials can be run locally, will I still need to create a Google Cloud account to complete the course?',
#   'data-engineering-zoomcamp',
#   '93dbebeb'),
#  ('Are there any additional requirements or configurations needed on my computer before starting the course, such as specific operating system or software versions?',
#   'data-engineering-zoomcamp',
#   '93dbebeb'),
#  ('Can I use AWS for this course and will there be any additional tools required?',
#   'data-engineering-zoomcamp',
#   'c2e1513d'),
#  ('Will I have access to support and resources if I am using AWS for this course?',
#   'data-engineering-zoomcamp',
#   'c2e1513d'),
#  ('Can I choose a different tool instead of the one provided for this course?',
#   'data-engineering-zoomcamp',
#   'c2e1513d'),
#  ('Also see Is it possible to use x tool instead of the one tool you use?',
#   'data-engineering-zoomcamp',
#   'c2e1513d'),
#  ('What if I encounter technical difficulties while working on my capstone project in AWS?',
#   'data-engineering-zoomcamp',
#   'c2e1513d'),
#  ('How will the quality of our projects be evaluated if some classmates are using AWS and others are not?',
#   'data-engineering-zoomcamp',
#   'c2e1513d'),
#  ('What is the format of the live zoom calls during Office Hour?',
#   'data-engineering-zoomcamp',
#   'b5ad3922'),
#  ('Will there be any additional opportunities for Q\\&A after the Capstone period?',
#   'data-engineering-zoomcamp',
#   'b5ad3922'),
#  ('Are live zoom calls the only way to get help from the instructor?',
#   'data-engineering-zoomcamp',
#   'b5ad3922'),
#  ('How far in advance will we know about any additional Office Hour opportunities?',
#   'data-engineering-zoomcamp',
#   'b5ad3922'),
#  ('Are live zoom calls recorded or part of the class record?',
#   'data-engineering-zoomcamp',
#   'b5ad3922'),
#  ('Will we be utilizing the NYC Trip data for January 2021, or will we be using data from 2022?',
#   'data-engineering-zoomcamp',
#   '6584a1b2'),
#  ("Can you confirm whether we will still be working with the same dataset as last year's project?",
#   'data-engineering-zoomcamp',
#   '6584a1b2'),
#  ('If so, where can I find access to the available NYC Trip data?',
#   'data-engineering-zoomcamp',
#   '6584a1b2'),
#  ('Are there any notable changes in methodology or analysis that I should be aware of when using this data?',
#   'data-engineering-zoomcamp',
#   '6584a1b2'),
#  ('Is it expected that the 2022 data will have a significant impact on our results, given that the project remains largely unchanged?',
#   'data-engineering-zoomcamp',
#   '6584a1b2'),
#  ("Can you clarify what 'here' refers to in the context of the 2022 repo, or is it an external link?",
#   'data-engineering-zoomcamp',
#   '4b609f57'),
#  ('Is there still access to the original 2022 repo, even though the material has been moved elsewhere?',
#   'data-engineering-zoomcamp',
#   '4b609f57'),
#  ('How did you decide which content from the 2022 repo should be moved and what was left behind?',
#   'data-engineering-zoomcamp',
#   '4b609f57'),
#  ('Can I expect any changes or updates to the course materials moving forward in terms of incorporating the 2022 repo content?',
#   'data-engineering-zoomcamp',
#   '4b609f57'),
#  ('Is it possible to obtain a record of the original URL for the 2022 repo, so that anyone following up on previous assignments can still access those resources?',
#   'data-engineering-zoomcamp',
#   '4b609f57'),
#  ('Can I use alternative tools besides Apache Airflow for my final project?',
#   'data-engineering-zoomcamp',
#   '0f9adc4d'),
#  ('Is it permissible to utilize an existing workflow engine, such as Airflow, for the final project?',
#   'data-engineering-zoomcamp',
#   '0f9adc4d'),
#  ('What are the requirements for selecting a tool for the final project in this course?',
#   'data-engineering-zoomcamp',
#   '0f9adc4d'),
#  ('Can I use any existing workflow management system or engine for my final project?',
#   'data-engineering-zoomcamp',
#   '0f9adc4d'),
#  ('Are there specific restrictions on choosing tools for the final project assignment?',
#   'data-engineering-zoomcamp',
#   '0f9adc4d'),
#  ("Is it possible to use tool 'X' instead of Mage for data integration and workflow management in the course?",
#   'data-engineering-zoomcamp',
#   '05538161'),
#  ('If I choose to use a different data stack, will you provide support if I run into issues with my tool or project?',
#   'data-engineering-zoomcamp',
#   '05538161'),
#  ('Can I use Prefect as an alternative to Mage for data pipeline development?',
#   'data-engineering-zoomcamp',
#   '05538161'),
#  ("How do I explain the difference between AWS and GCP products in my capstone project's peer review?",
#   'data-engineering-zoomcamp',
#   '05538161'),
#  ('Will you be able to provide feedback on my project if I decide to use a tool like Tableau instead of Metabase?',
#   'data-engineering-zoomcamp',
#   '05538161'),
#  ('How can I contribute to the course and help improve it?',
#   'data-engineering-zoomcamp',
#   '6c655a70'),
#  ("What is meant by 'starring' the repo, and how does it help?",
#   'data-engineering-zoomcamp',
#   '6c655a70'),
#  ("Can I create a pull request (PR) if I don't have coding experience?",
#   'data-engineering-zoomcamp',
#   '6c655a70'),
#  ('How do I go about creating a PR if I think I can improve something?',
#   'data-engineering-zoomcamp',
#   '6c655a70'),
#  ('Will my contributions be acknowledged or recognized in any way?',
#   'data-engineering-zoomcamp',
#   '6c655a70'),
#  ('What operating system (Windows, macOS, or Linux) is recommended for this course, and how compatible is it with the provided materials and tools?',
#   'data-engineering-zoomcamp',
#   '29b32b8d'),
#  ('Can I use any operating system of my choice during the course, or are there specific requirements that need to be met?',
#   'data-engineering-zoomcamp',
#   '29b32b8d'),
#  ("What if I have a slow computer or one that's not very powerful; will the course still be able to run smoothly?",
#   'data-engineering-zoomcamp',
#   '29b32b8d'),
#  ("If I'm using Linux, do I need to install any additional software or tools beyond what's already available in my distribution?",
#   'data-engineering-zoomcamp',
#   '29b32b8d'),
#  ('Are there any specific hardware requirements for running the materials and tools provided during the course, such as a certain processor speed or amount of RAM?',
#   'data-engineering-zoomcamp',
#   '29b32b8d'),
#  ("I've been trying to access modules with shell scripts (.sh files), but I'm a Windows user and keep hitting an error. Is there any workaround?",
#   'data-engineering-zoomcamp',
#   'b889fac7'),
#  ('How did past cohorts manage to navigate through modules containing .sh files without installing WSL or experiencing issues in git bash or MINGW64?',
#   'data-engineering-zoomcamp',
#   'b889fac7'),
#  ('Can you provide more information on why WSL environment setup is recommended from the start, especially for later modules like module-05 and RisingWave workshop?',
#   'data-engineering-zoomcamp',
#   'b889fac7'),
#  ("Are there any alternatives to setting up a WSL environment if I'm not comfortable with it?",
#   'data-engineering-zoomcamp',
#   'b889fac7'),
#  ('Will I be able to complete all modules with .sh files without having to set up a WSL environment, or will there be some kind of penalty or restriction for Windows users?',
#   'data-engineering-zoomcamp',
#   'b889fac7'),
#  ('What types of resources should I expect to find in this course?',
#   'data-engineering-zoomcamp',
#   '62667233'),
#  ('Are there any specific books or materials that are highly recommended for this course?',
#   'data-engineering-zoomcamp',
#   '62667233'),
#  ('How will I be able to stay up-to-date with the latest developments in data engineering during this course?',
#   'data-engineering-zoomcamp',
#   '62667233'),
#  ('Are there any specific projects or assignments that I can expect to work on in this course?',
#   'data-engineering-zoomcamp',
#   '62667233'),
#  ('Will there be opportunities for feedback and discussion with the instructor or peers during the course?',
#   'data-engineering-zoomcamp',
#   '62667233'),
#  ('Can I get any additional information about Project Attempt #1 and what it entails? Are there specific guidelines that I need to follow for this part of the project?',
#   'data-engineering-zoomcamp',
#   '85a3d59e'),
#  ('How will my performance in Project Attempt #1 affect Project Attempt #2, and are there any penalties for not meeting expectations in the first attempt?',
#   'data-engineering-zoomcamp',
#   '85a3d59e'),
#  ('What is the timeline for Project Attempt #1, and when can I expect to receive feedback on my submission if I need it?',
#   'data-engineering-zoomcamp',
#   '85a3d59e'),
#  ('Are there any specific criteria or outcomes that I should be aiming for with Project Attempt #1, or will they be determined by the instructor later?',
#   'data-engineering-zoomcamp',
#   '85a3d59e'),
#  ("Can I get clarification on what constitutes a 'late' submission for Project Attempt #1 - is this strictly based on the actual clock time submitted or can it include delays due to external circumstances?",
#   'data-engineering-zoomcamp',
#   '85a3d59e'),
#  ("1. I'm trying to troubleshoot an issue with my code, but I'm not sure where to start. The error message says that a certain column doesn't exist in my database, but I've double-checked my queries and they seem correct. What should I do first?",
#   'data-engineering-zoomcamp',
#   'cbf103a7'),
#  ("2. I'm experiencing an error when using the pgcli command, but it only shows the error description without any instructions on how to fix it. Is there a way to get more information about the issue?",
#   'data-engineering-zoomcamp',
#   'cbf103a7'),
#  ("3. I've tried restarting the app and checking the documentation, but nothing seems to be working. How do I troubleshoot issues that are not explicitly stated in the documentation?",
#   'data-engineering-zoomcamp',
#   'cbf103a7'),
#  ('4. I posted my question on Stackoverflow, but the answer is asking me to try some suggestions before posting further questions. What does this mean exactly? Should I go back and re-examine my code or follow the instructions in my original post?',
#   'data-engineering-zoomcamp',
#   'cbf103a7'),
#  ("5. I'm having trouble getting an error message to appear when I run a certain command. Is there a way to get screenshots of errors without taking pictures from my phone?",
#   'data-engineering-zoomcamp',
#   'cbf103a7'),
#  ("I'm getting an error message while coding, but I'm not sure what it means. Can you help me understand what's going wrong?",
#   'data-engineering-zoomcamp',
#   '59d39a80'),
#  ("I followed a tutorial that instructed me to run a specific command, but I'm getting an error message. How can I troubleshoot this?",
#   'data-engineering-zoomcamp',
#   '59d39a80'),
#  ('When asking a question, include as much information as possible: What are you coding on? What OS?',
#   'data-engineering-zoomcamp',
#   '59d39a80'),
#  ("I've checked my code for typos and other mistakes, but I still can't seem to fix the issue. Can you suggest what else I should check?",
#   'data-engineering-zoomcamp',
#   '59d39a80'),
#  ('What have you tried that did not work? This answer is crucial as without it, helpers would ask you to do the suggestions in the error log first.',
#   'data-engineering-zoomcamp',
#   '59d39a80'),
#  ("I'm using an online coding platform and I'm getting a strange error message. Can you help me understand what's going on?",
#   'data-engineering-zoomcamp',
#   '59d39a80'),
#  ('When asking a question, include as much information as possible: What are you coding on? What OS?',
#   'data-engineering-zoomcamp',
#   '59d39a80'),
#  ("I've tried various solutions to fix the issue, but nothing seems to work. Can you provide additional guidance or suggestions?",
#   'data-engineering-zoomcamp',
#   '59d39a80'),
#  ('What have you tried that did not work?',
#   'data-engineering-zoomcamp',
#   '59d39a80'),
#  ('How do I set up my local repository for this course, and what types of files should I ignore when committing to it?',
#   'data-engineering-zoomcamp',
#   '53bfd491'),
#  ('Can you provide more information about how to create a new repository for hosting my notes and file versions, and what is the best way to keep track of changes made by others?',
#   'data-engineering-zoomcamp',
#   '53bfd491'),
#  ("I'm not sure how to avoid accidentally storing sensitive information like passwords or keys in my Git repositories. Are there any specific settings or configuration options I should be using?",
#   'data-engineering-zoomcamp',
#   '53bfd491'),
#  ('Can you explain more about the difference between cloning a repository and creating a new one, and when would I use each approach?',
#   'data-engineering-zoomcamp',
#   '53bfd491'),
#  ("I've been having trouble getting started with Git and GitHub - are there any additional resources or tutorials beyond the links provided in the FAQ that might help me better understand how to use these tools for this course?",
#   'data-engineering-zoomcamp',
#   '53bfd491'),
#  ('Are there any keyboard shortcuts or commands available in VS Code that can quickly and easily convert existing spaces into actual tabs? If so, how do I access them?',
#   'data-engineering-zoomcamp',
#   'd1f0da1f'),
#  ("I'm running Linux on Windows Subsystem for Linux (WSL) 2 and I want to open an HTML file. What Internet Browser should I use?",
#   'data-engineering-zoomcamp',
#   '519ae769'),
#  ('If I already have a browser installed on my WSL guest, how do I set the default browser to be used with wslview?',
#   'data-engineering-zoomcamp',
#   '519ae769'),
#  ('Can I use wslview to view multiple types of files (e.g., PDFs, images) in addition to HTML files?',
#   'data-engineering-zoomcamp',
#   '519ae769'),
#  ("If I don't have a browser installed on my WSL guest, how can I install one using only the Windows host?",
#   'data-engineering-zoomcamp',
#   '519ae769'),
#  ('Are there any security implications or potential issues with using wslview to open files from my WSL guest?',
#   'data-engineering-zoomcamp',
#   '519ae769'),
#  ('1. Can you provide step-by-step instructions on how to set up Chrome Remote Desktop for Linux on Compute Engine? I want to ensure that my virtual machine instance is configured correctly.',
#   'data-engineering-zoomcamp',
#   '09329906'),
#  ('2. Why am I getting an "ERROR 403: Forbidden" when trying to download the 2021 yellow taxi trip records from the TLC website? Is there a workaround or alternative source of data?',
#   'data-engineering-zoomcamp',
#   '09329906'),
#  ("3. How do I extract the .gz file without using the `unzip` command? The instructions mention using `gzip -d`, but I'm not sure what this will achieve.",
#   'data-engineering-zoomcamp',
#   '09329906'),
#  ('4. What is the difference between the direct link to the data and the GitHub release link? Is one more reliable than the other?',
#   'data-engineering-zoomcamp',
#   '09329906'),
#  ('5. Are there any specific requirements or dependencies that I need to install on my Linux system before setting up Chrome Remote Desktop or accessing the yellow taxi trip records data?',
#   'data-engineering-zoomcamp',
#   '09329906'),
#  ("I've downloaded the taxi data files as *.csv.gz, but I'm having trouble reading them into pandas. Can you provide some guidance on how to handle this?",
#   'data-engineering-zoomcamp',
#   'fecbeb4f'),
#  ('I noticed that my data file has a different extension (csv.gz) than expected. How can I tell pandas to use it correctly?',
#   'data-engineering-zoomcamp',
#   'fecbeb4f'),
#  ("I'm having trouble understanding how to extract the file name from the URL. Can you provide an example of this process?",
#   'data-engineering-zoomcamp',
#   'fecbeb4f'),
#  ('In what format should I store my data file for best results? Should it be csv or csv.gz?',
#   'data-engineering-zoomcamp',
#   'fecbeb4f'),
#  ('Are there any other issues with reading taxi data files, aside from the file extension issue mentioned in the FAQ record?',
#   'data-engineering-zoomcamp',
#   'fecbeb4f'),
#  ('What is a data dictionary for NY Taxi data and why is it useful?',
#   'data-engineering-zoomcamp',
#   'c97649db'),
#  ('Can I download all available taxi trip data from the NYC government website?',
#   'data-engineering-zoomcamp',
#   'c97649db'),
#  ('1. How do I unzip a Parquet file that has been downloaded and is compressed with gzip?',
#   'data-engineering-zoomcamp',
#   'b75ead28'),
#  ('2. Can I directly use the Parquet file in my Python script to ingest data without having to convert it to CSV?',
#   'data-engineering-zoomcamp',
#   'b75ead28'),
#  ('3. What should I name my output csv file if I want to keep it consistent with the rest of my code?',
#   'data-engineering-zoomcamp',
#   'b75ead28'),
#  ('4. Is there a way to export the resulting DataFrame from `pd.read_parquet()` in JSON format instead of writing it to a CSV file?',
#   'data-engineering-zoomcamp',
#   'b75ead28'),
#  ('5. Can you provide an example of how to modify the provided ingest_data.py script to directly use the Parquet file without converting it to CSV?',
#   'data-engineering-zoomcamp',
#   'b75ead28'),
#  ("I'm trying to use wget in my Docker and Terraform project, but it's not recognized as an internal or external command. How do I install wget?",
#   'data-engineering-zoomcamp',
#   'e7769a27'),
#  ("I downloaded the wget binary from gnuwin32 and extracted it to my C:/tools/ directory, but it's still not recognizing wget as a command. What else do I need to do?",
#   'data-engineering-zoomcamp',
#   'e7769a27'),
#  ("Can I use Python's built-in wget library instead of the external wget command? How do I install it?",
#   'data-engineering-zoomcamp',
#   'e7769a27'),
#  ("I'm trying to download a file using wget in my Terraform script, but I'm getting an error. Is there another way to achieve this that doesn't involve installing wget?",
#   'data-engineering-zoomcamp',
#   'e7769a27'),
#  ("I've installed wget, but how do I use it correctly in my Terraform script? Do I just call `wget` directly, or is there a specific syntax I need to follow?",
#   'data-engineering-zoomcamp',
#   'e7769a27'),
#  ("I'm running wget command in a Jupyter Notebook and it's throwing an error about unverified certificate. How can I resolve this?",
#   'data-engineering-zoomcamp',
#   '29408b62'),
#  ("I'm using Python library wget from pip, but still getting the same error. What's the correct way to run wget in this case?",
#   'data-engineering-zoomcamp',
#   '29408b62'),
#  ('What is the difference between using --no-check-certificate and not verifying the certificate when running wget?',
#   'data-engineering-zoomcamp',
#   '29408b62'),
#  ('Can I use wget with a Python script to download files, or does it only work in the command line?',
#   'data-engineering-zoomcamp',
#   '29408b62'),
#  ("I'm using wget in a Mac environment, but getting an error. Can you walk me through the steps to resolve this issue?",
#   'data-engineering-zoomcamp',
#   '29408b62'),
#  ('I am using Git Bash for Windows and want to use backslashes in my commands. Is there a specific command I need to type?',
#   'data-engineering-zoomcamp',
#   'cc3f9d55'),
#  ('Do I need to modify any configuration files in .bashrc to make this work?',
#   'data-engineering-zoomcamp',
#   'cc3f9d55'),
#  ('Can I set this escape character globally for all future sessions without typing the command every time?',
#   'data-engineering-zoomcamp',
#   'cc3f9d55'),
#  ('Is it possible to configure this behavior by default when opening Git Bash for Windows?',
#   'data-engineering-zoomcamp',
#   'cc3f9d55'),
#  ("I'm not sure what bash.escapeChar=\\ does. Can you explain how it works or why I would use it? ",
#   'data-engineering-zoomcamp',
#   'cc3f9d55'),
#  ("I'm trying to use my personal API key with GitHub Codespaces, but I don't want it stored in my public repository. Can you provide instructions on how to securely store and manage account-specific secrets for GitHub Codespaces?",
#   'data-engineering-zoomcamp',
#   '78ec6d35'),
#  ('How do I enable secret storage for my GitHub Codespaces environment so that sensitive information like database credentials or API keys are protected?',
#   'data-engineering-zoomcamp',
#   '78ec6d35'),
#  ("I've heard of GitHub Codespaces, but I'm not sure if it integrates well with GitOps tools. Can you recommend any best practices for managing secrets and configurations using Terraform and GitHub Codespaces?",
#   'data-engineering-zoomcamp',
#   '78ec6d35'),
#  ('What is the difference between storing secrets in my local environment versus GitHub Codespaces, and which approach do you recommend for a development team working on a project?',
#   'data-engineering-zoomcamp',
#   '78ec6d35'),
#  ("I've set up secret storage for my GitHub Codespaces environment, but I'm not sure how to grant access to specific users or teams. Can you provide instructions on how to manage secret permissions in GitHub Codespaces?",
#   'data-engineering-zoomcamp',
#   '78ec6d35'),
#  ("I'm trying to run Docker commands in my WSL distribution, but I get an error message saying 'Cannot connect to Docker daemon at unix:///var/run/docker.sock.' What's going on?",
#   'data-engineering-zoomcamp',
#   '48d0425b'),
#  ('How do I ensure that my Docker daemon is running and accessible in WSL? The answer says to check the issue immediately below, but what exactly does it mean by that?',
#   'data-engineering-zoomcamp',
#   '48d0425b'),
#  ("I've tried running 'wsl --update' in PowerShell, but I still get the error message. Is there a specific order of operations or additional steps I need to take?",
#   'data-engineering-zoomcamp',
#   '48d0425b'),
#  ("If I'm using Docker Desktop on Windows and my WSL distribution is set up correctly, will I still encounter issues with the Docker daemon not running?",
#   'data-engineering-zoomcamp',
#   '48d0425b'),
#  ("Can someone please explain what 'unix:///var/run/docker.sock' means? Why does Docker use this specific location to connect to the daemon?",
#   'data-engineering-zoomcamp',
#   '48d0425b'),
#  ("I'm getting an error when trying to connect to Docker on Windows. What's the issue and how can I fix it?",
#   'data-engineering-zoomcamp',
#   'ee8da318'),
#  ("I'm a Windows 10 Home user trying to run Docker. What's the alternative method?",
#   'data-engineering-zoomcamp',
#   'ee8da318'),
#  ('I encountered an error while installing WSL2 (WslRegisterDistribution failed). How can I resolve this issue?',
#   'data-engineering-zoomcamp',
#   'ee8da318'),
#  ('Do I need to run Docker with elevated privileges on Windows?',
#   'data-engineering-zoomcamp',
#   'ee8da318'),
#  ('Are there any specific tutorials or instructions available for setting up Hyper-V and using it as the Docker backend?',
#   'data-engineering-zoomcamp',
#   'ee8da318'),
#  ("1. I'm trying to pull a Docker image named 'dbpage/pgadmin4', but I keep getting an error that says 'repository does not exist or may require 'docker login'. Can you explain why this is happening and how to fix it?\n\n2. I've set up Docker Desktop on my macOS M1, but when I try to run a PostgreSQL container with a mounted volume, I get a 'permission denied' error. What's causing this issue and how can I resolve it?\n\n3. Why do I need to execute `docker login` before pulling a private Docker image? Can you provide more information about private repositories and how they work?\n\n4. The Docker Images we're using in the course are public, but what happens if I try to pull an image that doesn't exist or is not accessible due to permission issues? How can I handle this situation?\n\n5. Are there any specific best practices for mounting volumes in Docker containers on macOS M1, and how can I ensure that I'm getting the correct permissions for my container?",
#   'data-engineering-zoomcamp',
#   'ffd7e49c'),
#  ("I was trying to delete a local folder that I mounted as a Docker volume, but it wouldn't let me because of permissions issues. What's going on and how can I resolve this?",
#   'data-engineering-zoomcamp',
#   '2fd7e6ac'),
#  ("I created a PostgreSQL database inside a Docker container using the 'docker run' command, but the container also created a folder on my local machine to mount it to the volume. How do I clean up this folder without losing any data?",
#   'data-engineering-zoomcamp',
#   '2fd7e6ac'),
#  ("Why does the folder that was created as a result of running the 'docker run' command have write and read protection, and why can't I delete it using the usual methods?",
#   'data-engineering-zoomcamp',
#   '2fd7e6ac'),
#  ("I'm having trouble accessing my Obsidian installation because the access error is related to the Docker volume. What are some possible solutions for this problem?",
#   'data-engineering-zoomcamp',
#   '2fd7e6ac'),
#  ("What's the most efficient way to remove a folder that was created as a result of running the 'docker run' command? The answer provided in the FAQ record mentions using the '-f' option with 'rm', but what does this do exactly?",
#   'data-engineering-zoomcamp',
#   '2fd7e6ac'),
#  ("I'm having trouble getting Docker to start or is it stuck on settings. What steps can I take to resolve this issue?",
#   'data-engineering-zoomcamp',
#   '06aa5f22'),
#  ('How do I know if I need to upgrade to the latest version of Docker for Windows, and where can I download it from?',
#   'data-engineering-zoomcamp',
#   '06aa5f22'),
#  ("If my Docker installation gets stuck, what's the best approach to switch between different operating systems while running containers?",
#   'data-engineering-zoomcamp',
#   '06aa5f22'),
#  ("I'm using the Pro Edition of Windows 10/11. How do I determine whether I should use Hyper-V or WSL2 as the backend for Docker Engine?",
#   'data-engineering-zoomcamp',
#   '06aa5f22'),
#  ('What is the recommended tutorial to enable Hyper-V as the back-end for Docker Engine on Windows 10/11 Pro Edition?',
#   'data-engineering-zoomcamp',
#   '06aa5f22'),
# ...
#   'data-engineering-zoomcamp',
#   '5ac4dee8'),
#  ('Can anyone else experience this issue, or is it just me with the Mage UI?',
#   'data-engineering-zoomcamp',
#   '5ac4dee8'),
#  ("Is there any way to avoid having to save and then edit later? I'm worried about losing changes.",
#   'data-engineering-zoomcamp',
#   '5ac4dee8'),
#  ('Are there any known issues or bugs related to this permission denied error that I should be aware of?',
#   'data-engineering-zoomcamp',
#   '5ac4dee8'),
#  ('1. How can I modify Solution n°2 to include more specific date filters, and what is the syntax for adding multiple filter conditions?',
#   'data-engineering-zoomcamp',
#   'fa9cfc54'),
#  ('2. In the provided solution for the ERROR: UndefinedColumn issue, how do I determine which option (open a Data Loader connect using SQL or open a Data Extractor of SQL) would be most efficient in my case?',
#   'data-engineering-zoomcamp',
#   'fa9cfc54'),
#  ('3. Can you provide more information about the `GcsFileSystem()` and `pa.fs.GcsFileSystem()` classes used in the code snippet? What are their differences, and how do they handle errors?',
#   'data-engineering-zoomcamp',
#   'fa9cfc54'),
#  ('4. Why is it necessary to increase the rows in the dataframe before running the SELECT statement for the Data Extractor of SQL? Is there a default row limit that can be exceeded?',
#   'data-engineering-zoomcamp',
#   'fa9cfc54'),
#  ('5. Are there any additional steps I should take after successfully loading the partitioned files into BigQuery, such as verifying data consistency or running data quality checks?',
#   'data-engineering-zoomcamp',
#   'fa9cfc54'),
#  ('What specific files should I submit for Homework 2 and how do I access them from MAGE?',
#   'data-engineering-zoomcamp',
#   '05086e4f'),
#  ('Where exactly can I find the mage files in my local machine?',
#   'data-engineering-zoomcamp',
#   '05086e4f'),
#  ('How do I download the entire pipeline from MAGE to my local machine?',
#   'data-engineering-zoomcamp',
#   '05086e4f'),
#  ("Can you clarify what type of files are stored under 'data loaders', 'data transformers' & 'data exporters'?",
#   'data-engineering-zoomcamp',
#   '05086e4f'),
#  ('Are there any specific steps or commands that I should follow when moving the downloaded files to my GitHub repo folder?',
#   'data-engineering-zoomcamp',
#   '05086e4f'),
#  ("I'm trying to include my personal Mage repo files along with the exercise files and homework in my Data Engineering Zoomcamp repository. Is it possible to do this without having to manually upload them, or is there an easier way?",
#   'data-engineering-zoomcamp',
#   'f3579207'),
#  ('When I add the Mage files to my main DE Zoomcamp repo, how do I ensure that GitHub can track all the changes made to both repositories simultaneously?',
#   'data-engineering-zoomcamp',
#   'f3579207'),
#  ("I'm not sure what 'cd into the Mage folder' means in the context of using the terminal. Can someone explain this step-by-step?",
#   'data-engineering-zoomcamp',
#   'f3579207'),
#  ('Can you elaborate on why removing the local git files and then running `git add .` is necessary? Is it safe to do so?',
#   'data-engineering-zoomcamp',
#   'f3579207'),
#  ('If I push my updated Mage repo to GitHub, will all the changes be reflected in the Data Engineering Zoomcamp repository as well?',
#   'data-engineering-zoomcamp',
#   'f3579207'),
#  ("I'm trying to filter a DataFrame where multiple conditions need to be met. However, I keep getting an error about the truth value of a Series being ambiguous. Can you explain what this means and how to fix it?",
#   'data-engineering-zoomcamp',
#   'e55a5600'),
#  ("In my code, I used `(data['passenger_count'] > 0) and (data['trip_distance'] > 0)` to filter a DataFrame. But now I've seen that `and` is replaced with `&`. Is this a change in syntax or a change in the way pandas works?",
#   'data-engineering-zoomcamp',
#   'e55a5600'),
#  ("I'm trying to add three assertions together: vendor_id being one of the existing values, passenger_count greater than 0, and trip_distance greater than 0. How can I do this correctly without getting an error about the truth value of a Series?",
#   'data-engineering-zoomcamp',
#   'e55a5600'),
#  ("After researching Stackoverflow for solutions, I changed my code from `(data['passenger_count'] > 0) and (data['trip_distance'] > 0)` to `((data['passenger_count'] > 0)) & ((data['trip_distance'] > 0))`. Is this the correct way to fix the issue?",
#   'data-engineering-zoomcamp',
#   'e55a5600'),
#  ('Can you provide an example of how to correctly use bitwise operators (`and`, `or`) with DataFrames in pandas? I want to make sure I understand the implications for my code.',
#   'data-engineering-zoomcamp',
#   'e55a5600'),
#  ("I'm experiencing issues with my Mage AI Files disappearing when I start a new session. Can you explain what's happening?",
#   'data-engineering-zoomcamp',
#   'ec55dddb'),
#  ("I've tried running 'docker compose up' again after closing and restarting the web interface, but the issue persists. What else can I try?",
#   'data-engineering-zoomcamp',
#   'ec55dddb'),
#  ("How do I know if I'm in the correct repository before running 'docker compose up'? Is there a specific command or check I should perform?",
#   'data-engineering-zoomcamp',
#   'ec55dddb'),
#  ("I've checked my progress and files were deleted when I booted up, but they weren't present initially. Can you tell me why this is happening?",
#   'data-engineering-zoomcamp',
#   'ec55dddb'),
#  ("I've tried restarting my PC twice to see if the issue would resolve itself, but it still persists. Are there any other troubleshooting steps I can take?",
#   'data-engineering-zoomcamp',
#   'ec55dddb'),
#  ("Can you provide more context on why 'at the trailing side' is an issue in io.config.yaml files? Is it related to a specific version of the file format?",
#   'data-engineering-zoomcamp',
#   'c9bbd3e7'),
#  ('Can you explain why Mage is unable to open the credentials file when trying to export data from GCS?',
#   'data-engineering-zoomcamp',
#   '23fdc067'),
#  ("What does the 'Permanent error GetBucketMetadata' mean, and how can I resolve it?",
#   'data-engineering-zoomcamp',
#   '23fdc067'),
#  ('Is there a specific folder structure required for Mage when using GCS, and what are the necessary files to include?',
#   'data-engineering-zoomcamp',
#   '23fdc067'),
#  ('How can I copy/paste the required service account credentials into the .json key file without any errors?',
#   'data-engineering-zoomcamp',
#   '23fdc067'),
#  ('What should I update in my code to point to the new credentials file, and what if I encounter any issues during this process?',
#   'data-engineering-zoomcamp',
#   '23fdc067'),
#  ("What are some additional resources or tutorials that can help me learn more about Google Cloud authentication if I'm still having trouble understanding it?",
#   'data-engineering-zoomcamp',
#   '23fdc067'),
#  ("I'm getting an error when trying to access a Google Cloud bucket using Mage - OSError. The error message says 'unable to create OAuth2 access token'. Can you provide more information on how to authenticate my request?",
#   'data-engineering-zoomcamp',
#   'f467bb80'),
#  ('The FAQ record mentions that the request was not sent due to lack of authentication token. What is an acceptable way to obtain this token, and are there any specific steps I need to follow?',
#   'data-engineering-zoomcamp',
#   'f467bb80'),
#  ('I see a link to learn more about Google Cloud authentication in the error message. Can you summarize the key points from this documentation that I should be aware of?',
#   'data-engineering-zoomcamp',
#   'f467bb80'),
#  ("The FAQ record mentions 'performwork() - curl error [6]=couldn't resolve host name'. How does this relate to my original issue with accessing the bucket, and are there any specific steps I can take to troubleshoot this?",
#   'data-engineering-zoomcamp',
#   'f467bb80'),
#  ('Is it possible that the retry policy exhaustion is a common issue in Mage workflow orchestration? Are there any best practices or guidelines for managing retries in this context?',
#   'data-engineering-zoomcamp',
#   'f467bb80'),
#  ("I'm trying to export data from Mage to a Google Cloud Storage bucket, but I'm getting a PermissionError with 'storage.buckets.get' denied. How can I resolve this issue?",
#   'data-engineering-zoomcamp',
#   '22daabed'),
#  ("What is the difference between having the 'Cloud Storage Admin' role and just having access to the GCS bucket? Does it affect my workflow?",
#   'data-engineering-zoomcamp',
#   '22daabed'),
#  ('Can I add the Cloud Storage Admin role to an existing service account, or do I need to create a new one?',
#   'data-engineering-zoomcamp',
#   '22daabed'),
#  ('If I have already assigned the required permissions to my service account but am still getting this error, what else could be causing the problem?',
#   'data-engineering-zoomcamp',
#   '22daabed'),
#  ("How can I verify that the Cloud Storage Admin role has been successfully added to my service account, and how will I know if it's working correctly?",
#   'data-engineering-zoomcamp',
#   '22daabed'),
#  ('I have written my pyspark script and I am ready to send it to Dataproc cluster. What are the next steps?',
#   'data-engineering-zoomcamp',
#   '96858b10'),
#  ('How do I create a Dataproc Cluster in GCP Console?',
#   'data-engineering-zoomcamp',
#   '96858b10'),
#  ('I have added the new role - Dataproc Editor to my service account, but now what?',
#   'data-engineering-zoomcamp',
#   '96858b10'),
#  ('How do I copy the python script to the correct path under GCS bucket?',
#   'data-engineering-zoomcamp',
#   '96858b10'),
#  ('I am trying to install gcloud cli in my Dockerfile, but getting errors. Can you provide more details on this?',
#   'data-engineering-zoomcamp',
#   '96858b10'),
#  ("I'm trying to install Docker-compose and it's taking an eternity. What's going on, and how do I speed up the process?",
#   'data-engineering-zoomcamp',
#   'cf0fce1d'),
#  ("I've heard that python ZipFile package is included in all modern python distributions. Can someone explain what this means for me, and why would I need to use it instead of apt-get?",
#   'data-engineering-zoomcamp',
#   'cf0fce1d'),
#  ("Is there a way to avoid using the -Y flag when installing zip/unzip packages for Linux? I'm not comfortable with automatically agreeing to install additional packages.",
#   'data-engineering-zoomcamp',
#   'cf0fce1d'),
#  ("I've installed Docker-compose successfully, but I'm still experiencing issues with unpacking datasets. Can you provide more information on how to troubleshoot this?",
#   'data-engineering-zoomcamp',
#   'cf0fce1d'),
#  ("How do I know which python distribution is 'modern' and includes the ZipFile package by default? Are there any specific versions or architectures that I should be using?",
#   'data-engineering-zoomcamp',
#   'cf0fce1d'),
#  ('I am experiencing an error when trying to write data from my web application to a Google Cloud Storage (GCS) bucket. The error message is indicating that there is a problem with the data type used in my query. Can you provide more information on how to resolve this issue? Specifically, what data types should I use for Nullable values?',
#   'data-engineering-zoomcamp',
#   '351b3407'),
#  ('I am using the GCS Bucket feature in Module 3 of your course and I noticed that it requires me to specify nullable data types when writing data from my web application. Can you explain why this is necessary and provide examples of how to implement nullable data types such as Int64?',
#   'data-engineering-zoomcamp',
#   '351b3407'),
#  ('I have been trying to write data from my web application to a GCS bucket but the error message keeps indicating that the data type used is not compatible with the Bucket feature. Can you provide more details on what data types are supported by GCS Bucket and how can I ensure that my data type matches?',
#   'data-engineering-zoomcamp',
#   '351b3407'),
#  ('I am having trouble understanding how to use nullable data types such as Int64 when writing data from my web application to a GCS bucket. Can you provide step-by-step instructions or examples of how to implement nullable data types in this context?',
#   'data-engineering-zoomcamp',
#   '351b3407'),
#  ('Can you clarify the difference between using nullable data types such as Int64 and not using them at all? How will this affect my data and the overall performance of my application?',
#   'data-engineering-zoomcamp',
#   '351b3407'),
#  ("1. What is the main reason why I'm getting an error when trying to create a table in BigQuery from a Parquet file with a column of type INT, but my target C++ type is DOUBLE?",
#   'data-engineering-zoomcamp',
#   '94384e41'),
#  ('2. Can you explain why the schema of my table is being overwritten by subsequent imports of files from different time periods? How can I prevent this from happening?',
#   'data-engineering-zoomcamp',
#   '94384e41'),
#  ("3. I'm trying to import FHV Datasets from 2019 into BigQuery, but some columns have a type of FLOAT, while others are INT. Is there a specific set of steps I need to follow to ensure that my data types match up correctly?",
#   'data-engineering-zoomcamp',
#   '94384e41'),
#  ("4. I've read that all files within a given directory must have the same schema when trying to ingest data into BigQuery. How do I enforce this when dealing with multiple files from different time periods?",
#   'data-engineering-zoomcamp',
#   '94384e41'),
#  ("5. Can you provide an example of how to use the pandas library to convert a DataFrame to a compatible format before uploading it to BigQuery, in order to avoid errors like the one I'm experiencing?",
#   'data-engineering-zoomcamp',
#   '94384e41'),
#  ("I keep getting an error when trying to import FHV data to my GCS bucket, it says 'gzip.BadGzipFile: Not a gzipped file (b'\\n\\n')'. What's going wrong?",
#   'data-engineering-zoomcamp',
#   '84acabfa'),
#  ('Can you explain why using the incorrect URL to the FHV dataset causes this error and how I can fix it?',
#   'data-engineering-zoomcamp',
#   '84acabfa'),
#  ("I'm having trouble with importing data from GitHub. How do I ensure I'm using the correct URL for the FHV dataset?",
#   'data-engineering-zoomcamp',
#   '84acabfa'),
#  ('If the URL of my specified FHV dataset is incorrect, what does the corrected URL look like?',
#   'data-engineering-zoomcamp',
#   '84acabfa'),
#  ("What's the significance of '/releases/download' in the correct URL for the FHV dataset?",
#   'data-engineering-zoomcamp',
#   '84acabfa'),
#  ("I am trying to load data from a URL into my GCS bucket, but I'm not sure how to set up the right credentials and configuration. Can you provide more information on this process?",
#   'data-engineering-zoomcamp',
#   'f3bb70cf'),
#  ('What is the best way to handle file extensions when loading data from a URL in GCP? Should we use wildcards or something else?',
#   'data-engineering-zoomcamp',
#   'f3bb70cf'),
#  ('How do I make sure my loaded data is correctly formatted for use in our analytics tools? Are there any specific formatting requirements?',
#   'data-engineering-zoomcamp',
#   'f3bb70cf'),
#  ('Can you explain the process of adding permissions to the GCS bucket so that other users can access the uploaded data?',
#   'data-engineering-zoomcamp',
#   'f3bb70cf'),
#  ('What are some common issues when loading large datasets from URLs and how can we troubleshoot them?',
#   'data-engineering-zoomcamp',
#   'f3bb70cf'),
#  ("I'm getting an error when querying my dataset from GCS Bucket - I see a Bad character (ASCII 0) error. What could be causing this?",
#   'data-engineering-zoomcamp',
#   '26a4b765'),
#  ('When uploading CSV.GZ files directly to the bucket without going through pandas, why does it still result in formatting issues?',
#   'data-engineering-zoomcamp',
#   '26a4b765'),
#  ("Can you explain what 'wrong formatting' means in this context, and how can I identify the specific issue?",
#   'data-engineering-zoomcamp',
#   '26a4b765'),
#  ('How do I avoid the Bad character (ASCII 0) error when querying from GCS Bucket if uploading files manually is not an option?',
#   'data-engineering-zoomcamp',
#   '26a4b765'),
#  ...]

# %%
import pandas as pd

df = pd.DataFrame(final_results, columns=['question', 'course', 'document'])

# %%
df.to_csv('ground-truth-data.csv', index=False)

# %%
# !head ground-truth-data.csv
# Out:
# question,course,document
# What is the expected start time of the course and how will it be communicated to students?,data-engineering-zoomcamp,5f1b0231
# How do I access the live 'Office Hours' session at the beginning of the course?,data-engineering-zoomcamp,5f1b0231
# Can I attend the course from a mobile device or only from a desktop computer?,data-engineering-zoomcamp,5f1b0231
# What is the deadline for registering before the course starts?,data-engineering-zoomcamp,5f1b0231
# Are there any other platforms besides Google Calendar and Slack that students should be aware of to stay updated on the course?,data-engineering-zoomcamp,5f1b0231
# What are the specific requirements I need to fulfill before starting this course?,data-engineering-zoomcamp,58fa8869
# Can you provide more details on what is meant by 'GitHub' in the context of course prerequisites?,data-engineering-zoomcamp,58fa8869
# Are there any additional tools or software that I need to install before enrolling in the course?,data-engineering-zoomcamp,58fa8869
# How do I link my GitHub account to access the required resources for the course?,data-engineering-zoomcamp,58fa8869
